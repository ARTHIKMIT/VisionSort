# %% [markdown]
# # VisionSort: YOLOv8 Classification Training
#
# This notebook demonstrates how to train a YOLOv8 classification model on the TrashNet dataset. It covers data downloading, splitting, and training.

# %%
# Install dependencies if running in Colab
# !pip install ultralytics gdown scikit-learn pandas

# %%
import os
import shutil
import random
from ultralytics import YOLO

# See ml/train.py for the full script equivalent of this notebook.
